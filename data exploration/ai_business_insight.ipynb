# %%
import os
import openai
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
from dotenv import load_dotenv

# Load environment variables from the parent directory
load_dotenv(dotenv_path=os.path.join("../.env"))

# Retrieve the API key
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise ValueError("OPENAI_API_KEY is not set. Check your .env file.")

client = openai.OpenAI(api_key=OPENAI_API_KEY)

# %%
conn = psycopg2.connect(
    dbname="postgres", 
    user="root", 
    password="password1", 
    host="localhost", 
    port="5432"
)

# Load data into a DataFrame
query = 'SELECT * FROM "Issue"'
df = pd.read_sql(query, conn)

# Define column mapping
column_mapping = {
    "Summary": "summary",
    "Description": "description",
    "Comments": "comments"
}
df.rename(columns=column_mapping, inplace=True)
# Out:
# /tmp/ipykernel_87866/3541435462.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
prompts = f'''
       You are a business analyst assistant helping to review IT service ticket data for a non-profit food bank. Each ticket includes an initial desciption that starts the interaction and a  "comments" field written by users and IT help.
It has the idescribing their experience, frustration, praise, or suggestions.

Analyze the following comments to extract meaningful business insights. Focus on identifying:

Common themes or recurring problems

User sentiments (positive, negative, neutral)

Suggestions or implicit requests for improvement

Any operational inefficiencies or team feedback that could help improve service

Respond with a concise summary of 20 insights that could inform decision-making, followed by specific examples if applicable.
Context:

{df[['description', 'comments']]}
'''

# %%
response = openai.chat.completions.create(
            model="gpt-4o-mini",
            messages=[{"role": "system", "content": "You are an IT support business analyst."},
                      {"role": "user", "content": prompts}],
        )
        
        # Extract category and subcategory for each response
content = response.choices[0].message.content.strip()

# %%
for i in content.split('\n\n'):
    print(i)
    print('-'*100)
# Out:
# Based on the provided service ticket data, here are 20 insights that could inform decision-making for the non-profit food bank:
# ----------------------------------------------------------------------------------------------------
# ### Common Themes or Recurring Problems
# 1. **Cancellation Requests**: Several tickets are related to users needing to cancel orders, indicating potential confusion around the order process or system.
#    - *Example*: Users frequently mention they have sent emails to cancel, but may not receive timely confirmations.
# ----------------------------------------------------------------------------------------------------
# 2. **Request for Additional Supplies**: Users commonly request to add cases of specific supplies to their orders.
#    - *Example*: "Can you please add 25 cases of the following to my order?" highlights a need for efficient order adjustment processes.
# ----------------------------------------------------------------------------------------------------
# 3. **Delayed Responses**: Users express frustration over waiting for responses to their requests or questions.
#    - *Example*: Comments indicate users feel neglected when they do not receive timely updates.
# ----------------------------------------------------------------------------------------------------
# 4. **System Downtime**: Some comments suggest that users are experiencing issues with the ticketing or ordering system being down or slow.
#    - *Example*: Users report being unable to place orders during peak times.
# ----------------------------------------------------------------------------------------------------
# 5. **Miscommunication**: Users often mention misunderstandings related to order statuses and shipment tracking.
#    - *Example*: Comments indicate confusion on whether an order has been dispatched.
# ----------------------------------------------------------------------------------------------------
# ### User Sentiments
# 6. **Negative Sentiment on Delays**: Many comments reflect frustration due to delays and lack of communication.
#    - *Example*: Users expressing that they feel ignored when feedback is not acknowledged.
# ----------------------------------------------------------------------------------------------------
# 7. **Frustration with System Usability**: Some users detail challenges with navigating the IT support system or website.
#    - *Example*: "I struggled to log in to check my orders," shows a notable pain point in accessibility.
# ----------------------------------------------------------------------------------------------------
# 8. **Positive Feedback on Support**: Users do appreciate the help when they receive timely support.
#    - *Example*: "Thanks for your quick response!" indicates favorable experiences.
# ----------------------------------------------------------------------------------------------------
# 9. **Expectations of Support**: Users expect faster resolutions compared to current response times.
#    - *Example*: "I wish I didn't have to wait so long for help," expresses a genuine expectation of service speed.
# ----------------------------------------------------------------------------------------------------
# ### Suggestions for Improvement
# 10. **Enhanced Communication**: Users suggest regular updates regarding their tickets or order statuses.
#     - *Example*: "It would help if I received a confirmation email after I cancel my order."
# ----------------------------------------------------------------------------------------------------
# 11. **User Training and Resources**: Creating tutorials or FAQs could help users navigate the system better.
#     - *Example*: Comments point to the need for better onboarding resources.
# ----------------------------------------------------------------------------------------------------
# 12. **Increase Staffing During Peaks**: Users have mentioned that they experience longer wait times during busy periods, suggesting possible staffing increases.
#     - *Example*: “I waited for an hour during food drop-off days.”
# ----------------------------------------------------------------------------------------------------
# 13. **System Improvements or Upgrades**: Some users indicate that the platform feels outdated and could benefit from modernization.
#     - *Example*: Feedback hints at wanting a more intuitive design and faster load times.
# ----------------------------------------------------------------------------------------------------
# 14. **Feedback Loop Implementation**: Users express the desire to provide feedback on their experiences for continued improvement.
#     - *Example*: Suggestions for a post-interaction survey to capture user satisfaction.
# ----------------------------------------------------------------------------------------------------
# ### Operational Efficiencies and Team Feedback
# 15. **Standardize Responses for Common Issues**: Automating responses for frequent inquiries could save time and improve user satisfaction.
#     - *Example*: Quick responses for cancellation protocols could streamline the process.
# ----------------------------------------------------------------------------------------------------
# 16. **Document Common Issues in a Knowledge Base**: Building an internal resource for IT support staff based on recurring themes could expedite ticket resolutions.
#     - *Example*: Developing a guide based on common troubleshooting steps based on user comments.
# ----------------------------------------------------------------------------------------------------
# 17. **Team Collaboration**: Strengthening inter-departmental communication may prevent misinformation related to order statuses.
#     - *Example*: Ensuring logistics and IT staff are in sync could reduce user confusion.
# ----------------------------------------------------------------------------------------------------
# 18. **Implement a Ticket Escalation Process**: Users could benefit from an escalated response for high-priority issues, especially during delays.
#     - *Example*: Propose a policy for urgent tickets to ensure timely follow-up.
# ----------------------------------------------------------------------------------------------------
# 19. **Assess IT System Load**: Analyzing the system’s performance during peak usage can help identify necessary upgrades or changes.
#     - *Example*: Comments about slow speeds might correlate with specific busy periods, highlighting the need for performance enhancement.
# ----------------------------------------------------------------------------------------------------
# 20. **Regular Staff Training on User Interaction**: Ongoing training for IT staff to improve customer service skills could lead to better user experiences.
#     - *Example*: “I felt dismissed when my issue was not thoroughly addressed,” suggests a need for responsiveness training.
# ----------------------------------------------------------------------------------------------------
# ### Summary
# Collecting, analyzing, and acting on these insights could significantly enhance user experience, streamline operations, and improve overall IT support efficiency within the food bank. The focus on communication, user training, and system upgrades presents a path forward to address many of the concerns highlighted by users.
# ----------------------------------------------------------------------------------------------------

# %%
prompts = f'''
       You are a data scientist helping to review IT service ticket data for a non-profit food bank. 
       Each ticket includes an initial desciption that starts the interaction and a  "comments" field written by users and IT help.
       Using the columns and data below, come up with a plan to create priority scores for each ticket.
       These will then used to elevate tickets that need immediate attention.
       Create the scoreing, then create a prompt that can be used by a gpt model to score the tickets.

{df.head(100)}
'''

# %%
response = openai.chat.completions.create(
            model="gpt-4o-mini",
            messages=[{"role": "system", "content": "You are an IT support business analyst."},
                      {"role": "user", "content": prompts}],
        )
        
        # Extract category and subcategory for each response
content = response.choices[0].message.content.strip()

# %%
content = response.choices[0].message.content.strip()

# %%
for i in content.split('\n\n'):
    print(i)
    print('-'*100)
# Out:
# To create a priority scoring system for the IT service tickets at a non-profit food bank, we need to outline a method to evaluate each ticket based on several critical factors. The goal is to identify which tickets require immediate attention and those that can be addressed later.
# ----------------------------------------------------------------------------------------------------
# ### Step 1: Define the Scoring Criteria
# We will develop a scoring system based on various parameters within the ticket data. Below are the potential criteria that can be used to assess the urgency and importance of each ticket:
# ----------------------------------------------------------------------------------------------------
# 1. **Summary Keywords**: Identify keywords in the summary that indicate urgency (e.g., "urgent," "important," "tomorrow," "ASAP"). Each keyword can add to the score.
#
# 2. **Comment Analysis**: Analyze comments for language signaling urgency. Negative sentiment or expressions of frustration can increase priority.
# ----------------------------------------------------------------------------------------------------
# 3. **Time to Resolution**: Tickets that have a longer average time to resolution may warrant a higher priority score, especially if they exceed a certain threshold (e.g., 7 days).
# ----------------------------------------------------------------------------------------------------
# 4. **Status**: Tickets that are "Closed" will likely receive a lower priority score. Open tickets can hold higher scores.
# ----------------------------------------------------------------------------------------------------
# 5. **Project Category**: Certain projects or categories might be considered more critical. For example, operations affecting food distribution might get higher priority.
# ----------------------------------------------------------------------------------------------------
# 6. **Assignee Workload**: If an assignee has many unresolved tickets, prioritize tickets assigned to them higher.
# ----------------------------------------------------------------------------------------------------
# 7. **Ticket Age**: Older tickets should be flagged more urgently especially if they haven’t been resolved.
# ----------------------------------------------------------------------------------------------------
# ### Step 2: Assigning Weight to Scoring Criteria
# Each factor could carry different weights, which can be adjusted based on the specific context or organizational needs:
# ----------------------------------------------------------------------------------------------------
# - Summary Keywords: 2 points per keyword
# - Comments Sentiment (Negative): +3 points
# - Time to Resolution (each day over 7 days): +1 point
# - Status (Open: +5 points, Closed: +0 points)
# - Project Category (Critical: +4 points, Normal: +0 points)
# - Assignee Workload (if above a threshold): +2 points
# - Ticket Age (each week): +1 point
# ----------------------------------------------------------------------------------------------------
# ### Step 3: Creating the Priority Score Formula
# A sample formula to compute the priority score could look like this:
# ----------------------------------------------------------------------------------------------------
# ```
# priorityScore = (Sum of Keywords) * 2 + (Negative Comments Count * 3) + (Time Over 7 Days) + (Open Status * 5) + (Critical Category * 4) + (High Assignee Workload * 2) + (Old Ticket Age in Weeks)
# ```
# ----------------------------------------------------------------------------------------------------
# ### Step 4: Implementation of the Scoring Model using a GPT prompt
# Once the scoring system is established, you can automate the scoring process using a machine learning model or simpler logic via a prompt directed at a GPT model. Here’s a sample prompt that can be used:
# ----------------------------------------------------------------------------------------------------
# ```markdown
# You are a data scorer analyzing IT service tickets for a non-profit food bank. For each ticket, score its priority based on the following criteria:
# ----------------------------------------------------------------------------------------------------
# 1. Summary Keywords:
#    - "urgent," "important," "immediate," "tomorrow" = 2 points each.
# ----------------------------------------------------------------------------------------------------
# 2. Comments Sentiment:
#    - Look for negative sentiment. Each instance increases the score by 3 points.
# ----------------------------------------------------------------------------------------------------
# 3. Time to Resolution:
#    - If the ticket has been open over 7 days, add a point for each day over.
# ----------------------------------------------------------------------------------------------------
# 4. Status:
#    - Open tickets = 5 points, Closed tickets = 0 points.
# ----------------------------------------------------------------------------------------------------
# 5. Project Category:
#    - If the ticket is categorized as 'critical', add 4 points.
# ----------------------------------------------------------------------------------------------------
# 6. Assignee Workload:
#    - If the assignee has more than 10 unresolved tickets, add 2 points.
# ----------------------------------------------------------------------------------------------------
# 7. Ticket Age:
#    - For each week the ticket is old, add 1 point.
# ----------------------------------------------------------------------------------------------------
# Please provide the final priority score for the following ticket details:
# - Summary: "{summary}"
# - Comments: "{comments}"
# - Time to Resolution: {timeToResolution}
# - Status: {status}
# - Project Category: "{category}"
# - Assignee: "{assignee}"
# - Date of First Response: "{dateOfFirstResponse}"
# ```
# ### Step 5: Calculating and Storing Priority Scores
# Once the prompt is refined and data is plugged into it, the output can be saved back into the ticket data structure (in the `priorityScore` column) for further analysis.
# ----------------------------------------------------------------------------------------------------
# Implementing the above plan should help the non-profit food bank prioritize their IT service tickets more effectively, ensuring that urgent issues are addressed promptly.
# ----------------------------------------------------------------------------------------------------

# %%
import re
from textblob import TextBlob
from datetime import datetime
def score_ticket(row, assignee_ticket_counts):
    score = 0
    if row['status'].lower() == 'closed':
        return 0
    # 1. Summary keywords
    keywords = [
    "urgent", "immediate", "important", "asap", "critical", "emergency",
    "high priority", "unusable", "broken", "system down", "not working",
    "failure", "crashed", "inaccessible", "deadline", "today", "tomorrow",
    "locked out", "can't login", "issue needs resolution", "need now",
    "priority", "pressing", "as soon as possible", "need access",
    "blocking", "stuck", "outage", "halted", "failure to load", "can't connect",
    "high severity", "server down", "production issue", "needs fixing now", 'now', 
    
]
    score += sum(2 for kw in keywords if kw in row['summary'].lower())
    
    # 2. Comments sentiment
    if pd.notna(row['comments']):
        blob = TextBlob(row['comments'])
        if blob.sentiment.polarity < 0:
            score += 3
    
    # 3. Time to resolution (if still open)
    if row['status'].lower() == 'open':
        days_open = (datetime.now() - pd.to_datetime(row['created'])).days
        if days_open > 7:
            score += days_open - 7

    # 4. Status
    if row['status'].lower() == 'open':
        score += 5

    # 5. Project category
    if str(row.get('priority', '')).lower() == 'critical':
        score += 4

    # 6. Assignee workload
    if assignee_ticket_counts.get(row['assignee'], 0) > 10:
        score += 2

    # 7. Ticket age
    created_date = pd.to_datetime(row['created'])
    weeks_old = (datetime.now() - created_date).days // 7
    score += weeks_old

    return score
open_tickets = df[df['status'].str.lower() == 'open']
assignee_ticket_counts = open_tickets['assignee'].value_counts().to_dict()
df['formula_priority'] = df.apply(lambda row: score_ticket(row, assignee_ticket_counts), axis=1)

# %%
df.sort_values(by='formula_priority', ascending=False, inplace=True)
for i in df[['summary', 'description', 'formula_priority']].itertuples():
    print(i.summary)
    print(i.description)
    print(i.formula_priority)
    print('-'*100)
# Out:
# Refund/Return SO156281
# Good morning,
#
#
#
# This is to let you know that we received the above mentioned last Friday, 4/26/2024, that included chicken drumsticks, item #300435, but the total amount, $1,748, was not covered by the grant, only $1,639.06 was covered by the grant. Please any idea what might have caused this since we had enough grant money to cover the total amount at the time of order?
#
#
#
# Thank you,
#
# Kunle
# 50
# ----------------------------------------------------------------------------------------------------
# Shopping Menu Questions 362014 Eggs, 30 dozen 30/24 oz Carton
# Good morning,
#
#
#
# Please is this item just liquid egg or regular egg in a shell? I just wanted to be sure.
#
#
#
# Thank you.
# 28
# ----------------------------------------------------------------------------------------------------
# Access to Washington View Account
# Hi,
#
# When I sign into my account, it looks like I only have access to Villages of East River. I need access to Washington View, our newest site. If possible, I would also like to gain access to our other NHT sites: Galen Terrace, R St., and Mass Place Apartments.
#
# Thanks!
#
#
#
# Raisa
# 23
# ----------------------------------------------------------------------------------------------------
# Shopping Menu Questions Turkeys
# Hello our agency would like to buy a lot of Turkeys.  Can you keep us in mind and let us know when you have some.  Thanks so much for your assistance.
# 21
# ----------------------------------------------------------------------------------------------------
# Pickup / Delivery Support so189347
# I have a delivery currently scheduled for Tuesday, December 24th, and I would like to inquire if itâ€™s possible to reschedule it to Monday, December 23rd instead.
# 16
# ----------------------------------------------------------------------------------------------------
# You can't back up the feed without compressing the bluetooth ADP system!
# Bis commodi corrigo conqueror. Quasi victus porro catena conforto amplus ab fugit speciosus apto. Tumultus amita ultra coadunatio quisquam veritas speciosus acerbitas.
# 11
# ----------------------------------------------------------------------------------------------------
# Add to order SO197317 for 02.28.25 Delivery SO197317
# Would like to add 1/2000 4 Way Mixed pallet of 97317 to order
#
# Would like to add 1/700 Apples of 800111
#
# Thank you.
# 10
# ----------------------------------------------------------------------------------------------------
# Fw: Damaged food
# {color:#172B4D}Hi "D",{color}{color:#172B4D}{color}
#
# {color:#172B4D} Passing this along directly to you as we have received quite a few complaints about the canned peaches. Did you ever hear back from the Warehouse about if they have been able to check the rest of the boxes? Also are you all able to connect with Emily directly about her refund request?{color}{color:#172B4D}{color}
#
# {color:#172B4D} Thank you,{color}
# {color:#172B4D} Alanna{color}{color:#172B4D}{color}
# ----
#
#  {color:#172B4D}*From:* Emily Ewing <yiayianse@yahoo.com>
#   *Sent:* Sunday, February 23, 2025 8:41 AM
#   *To:* Alanna King <aking@capitalareafoodbank.org>
#   *Subject:* Damaged food{color}
# Alanna
#
# We received a delivery of food on Tuesday, February 18. Everything was fine except for one case of peaches. 17 cans out of 24 in the case were damaged. I have pictures below. The cans with the black spots are holes where the juice leaked out. The two cans on paper had leaked and were stuck to the paper. You can see all the cans that were wet. We cannot give out food that is stained like this; plus, we have no way of knowing if the contents are bad. We could use only 7 cans from this box. Since prices are so much higher now and our money is tighter, we would like a refund.
#
# I have not heard anything about the cans of pears that were damaged a few weeks ago.
#
# Have a good week. Emily
#
# Emily Ewing  West End Food Pantry. PS: ignore the last picture of drills; I donâ€™t know how to delete it!
#
# !4BDB06D6-5EFF-4BD3-A378-90169C6B3906.jpeg|thumbnail!!71D25F36-D694-4AEB-8E30-B9DD8A93806B.jpeg|thumbnail!!14A0C6D5-AFCC-4992-ABE8-E98FC87F13B0.jpeg|thumbnail!!BCB6CBB9-3158-47C8-A38C-B36BBB2C784A.jpeg|thumbnail!!E0C65F92-EE69-4D29-85F7-0ECB35BA4E0B.jpeg|thumbnail!!A88C4015-264C-4AF0-AFA3-B8E4EFB18B52.jpeg|thumbnail!!8958B738-4AB5-427C-B35D-986538387B87.jpeg|thumbnail!{adf}{"type":"expand","content":[{"type":"mediaSingle","attrs":{"layout":"center"},"content":[{"type":"media","attrs":{"type":"file","id":"UNKNOWN_MEDIA_Outlook-A picture .png","collection":"","height":183,"width":200}}]},{"type":"paragraph","content":[{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"Alanna King","marks":[{"type":"strong"},{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":" (she/her)","marks":[{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"Partnership Specialist, VA Region","marks":[{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"Capital Area Food Bank","marks":[{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"P.","marks":[{"type":"strong"},{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":" 571.482.4773 |","marks":[{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":"  "},{"type":"text","text":"aking@capitalareafoodbank.org","marks":[{"type":"underline"},{"type":"textColor","attrs":{"color":"#0563c1"}},{"type":"link","attrs":{"href":"mailto:aking@capitalareafoodbank.org"}}]},{"type":"text","text":"  "}]},{"type":"paragraph","content":[{"type":"text","text":"6833 Hill Park Dr, Lorton, VA 22079","marks":[{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"capitalareafoodbank.org","marks":[{"type":"underline"},{"type":"textColor","attrs":{"color":"#4e8227"}},{"type":"link","attrs":{"href":"http://capitalareafoodbank.org/"}}]},{"type":"text","text":"  "}]},{"type":"mediaSingle","attrs":{"layout":"center"},"content":[{"type":"media","attrs":{"type":"file","id":"UNKNOWN_MEDIA_Outlook-2st4tlju.png","collection":"","height":183,"width":200}}]},{"type":"paragraph","content":[{"type":"text","text":"<","marks":[{"type":"textColor","attrs":{"color":"#172b4d"}}]},{"type":"text","text":"https://www.facebook.com/CapitalAreaFoodBank","marks":[{"type":"link","attrs":{"href":"https://www.facebook.com/CapitalAreaFoodBank"}},{"type":"textColor","attrs":{"color":"#172b4d"}}]},{"type":"text","text":">","marks":[{"type":"textColor","attrs":{"color":"#172b4d"}}]}]},{"type":"mediaSingle","attrs":{"layout":"center"},"content":[{"type":"media","attrs":{"type":"file","id":"UNKNOWN_MEDIA_Outlook-qsl3r4sr.png","collection":"","height":183,"width":200}}]},{"type":"paragraph","content":[{"type":"text","text":"<","marks":[{"type":"textColor","attrs":{"color":"#172b4d"}}]},{"type":"text","text":"https://www.linkedin.com/company/capitalareafoodbank","marks":[{"type":"link","attrs":{"href":"https://www.linkedin.com/company/capitalareafoodbank"}},{"type":"textColor","attrs":{"color":"#172b4d"}}]},{"type":"text","text":">","marks":[{"type":"textColor","attrs":{"color":"#172b4d"}}]},{"type":"text","text":" "}]},{"type":"mediaSingle","attrs":{"layout":"center"},"content":[{"type":"media","attrs":{"type":"file","id":"UNKNOWN_MEDIA_Outlook-nz1nqtct.png","collection":"","height":183,"width":200}}]},{"type":"paragraph","content":[{"type":"text","text":"<","marks":[{"type":"textColor","attrs":{"color":"#172b4d"}}]},{"type":"text","text":"https://twitter.com/foodbankmetrodc","marks":[{"type":"link","attrs":{"href":"https://twitter.com/foodbankmetrodc"}},{"type":"textColor","attrs":{"color":"#172b4d"}}]},{"type":"text","text":">","marks":[{"type":"textColor", ...
# 10
# ----------------------------------------------------------------------------------------------------
# SO194429 - Mice Incident Report
# {color:#172B4D}Dear Partner Support,{color}{color:#172B4D}{color}
#
# {color:#172B4D} Last Friday, 2/14/25, sale order SO194429 was delivered to our location. It included 3 bins of cereal, item 100862. At first sight, we noticed rodent droppings on top of cereal boxes in one of those bins. That bin was not accepted and the delivery driver loaded it back up inside his truck.{color}
#  {color:#172B4D}The other two bins were b{color} {color:#b36ae2}*r*{color}{color:#172B4D}ought upstairs to our storage room. To our surprise, a few minutes later, we saw a mouse coming out of one bin and returning inside that bin.{color}
# {color:#172B4D} We had to act quickly since other food items were stored inside this room. We immediately wrapped both bins, loaded them inside our vehicle and drove to two landfill sites to dispatch the two open bins with donated assorted cereal. Upon dispatching them, our staff saw two mice. This confirmed our fear that more than one mouse had entered inside our building and our storage room through the open bin cereals that we ordered.{color}
# {color:#172B4D} Of course, the issue was not over and the following Monday, 2/17/25, we caught another mouse. We will continue to closely monitor our storage room and other areas to be certain that the problem has been eradicated. Attached are pictures of what was left behind after we removed the two bins out of the storage room.{color}
# {color:#172B4D} This experience was very disturbing, and a solution needs to be implemented quickly. This put us behind schedule by four days due to the intervention that we put in place. We also had to throw away our products that the mice had contaminated.{color}
# {color:#172B4D} CAFB has been such a great partner to us and we are forever grateful for the 'all in' support that you have been providing us to allow us to help our underserved communities. That is why we are sharing this information and our experience to you so this can be further looked at and hopefully avoided. We are in this together to strengthen food security, so we know this kind of issue will be attended to and taken seriously by both parties.{color}
# {color:#172B4D} We look forward to your feedback or resolution around this matter.{color}
#  {color:#b36ae2}{color}
#
# {color:#172B4D} Thank you and Best regards,{color}
# {color:#172B4D} Anna Beavan and Jeannette Mendy{color}{color:#172B4D}{color}{color:#111111}{color}
#
#
# {color:#111111} Jeannette Mendy{color}{adf}{"type":"expand","content":[{"type":"paragraph","content":[{"type":"text","text":"Workforce Development Manager","marks":[{"type":"textColor","attrs":{"color":"#111111"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"LindaBen Foundation Inc.","marks":[{"type":"textColor","attrs":{"color":"#111111"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"Cell: (646) 420-0787","marks":[{"type":"textColor","attrs":{"color":"#111111"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"PGC: 11720 Beltsville Drive, Ste 500 M8, Beltsville, Maryland 20705","marks":[{"type":"textColor","attrs":{"color":"#111111"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"HoCo:9770 Patuxent Woods Drive, Ste 333, Columbia, Maryland 21046","marks":[{"type":"textColor","attrs":{"color":"#111111"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"Web:","marks":[{"type":"textColor","attrs":{"color":"#424242"}}]},{"type":"text","text":"  "},{"type":"text","text":"http://www.lindabenfoundation.org","marks":[{"type":"link","attrs":{"href":"https://linkprotect.cudasvc.com/url?a=http%3a%2f%2fwww.lindabenfoundation.org%2f&c=E,1,BBeYbx3ugNuB_oEtSlixx9Ua6osNHhADkY-7AhXp-U66lC1QH0nsPcg4IsFTEeNJxwkKqx25kyjqG47AzeV8l2QkIs_yTHKwGNvLSGufv7CSLSGjq0zJqVSnfQ,,&typo=1"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"Instagram:","marks":[{"type":"textColor","attrs":{"color":"#424242"}}]},{"type":"text","text":"  "},{"type":"text","text":"@lindabenfoundationinc","marks":[{"type":"textColor","attrs":{"color":"#0c64c0"}},{"type":"link","attrs":{"href":"https://www.instagram.com/lindabenfoundationinc/"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"Facebook:","marks":[{"type":"textColor","attrs":{"color":"#424242"}}]},{"type":"text","text":"  ["},{"type":"text","text":"Lindaben Foundation | Facebook","marks":[{"type":"textColor","attrs":{"color":"#0c64c0"}}]},{"type":"text","text":"|https://www.facebook.com/LindabenFoundation] "}]},{"type":"paragraph","content":[{"type":"text","text":"Twitter:","marks":[{"type":"textColor","attrs":{"color":"#424242"}}]},{"type":"text","text":"  "},{"type":"text","text":"@LindabenCares / Twitter","marks":[{"type":"textColor","attrs":{"color":"#0c64c0"}},{"type":"link","attrs":{"href":"https://twitter.com/lindabencares"}}]},{"type":"text","text":"  "}]},{"type":"paragraph","content":[{"type":"text","text":"We are 501(c) (3) tax-exempt organization (EIN: 85-2409722)","marks":[{"type":"textColor","attrs":{"color":"#172b4d"}}]}]}],"attrs":{"title":"Signature"}}{adf}
# 10
# ----------------------------------------------------------------------------------------------------
# How to add a new order to an existing order
# Hello, my name is Pamela Sturdivant from Faith United Ministries #4830-01.
# My issue is I have an order being delivered on 3-3-2025, and items we needed
# just became available today (2-24-2025). I went ahead and set up a delivery of
# the items but it requested a new delivery date and to pay an additional delivery fee.
# The new invoice is #SO197349. I wanted to know if this ordered can be added to
# my previous order.
# Thank you,
# Pamela Sturdivant
# 10
# ----------------------------------------------------------------------------------------------------
# 19776-PART-01 Exceeded Pounds Limit
# [Friends Of Douglass Community Center|/app/common/entity/custjob.nl?whence=&id=2293] has exceed their Produce pound limit on their last Sales Order.
#
# [View Record|https://229676.app.netsuite.com/app/common/custom/custrecordentry.nl?rectype=769&id=3891&c=229676]
# 10
# ----------------------------------------------------------------------------------------------------
# Missing Items SO195766
# City of Praise Ministry
#
# *SO195766*
#
# Missing item [827047 Produce Pallet - 3 WAY - Potatoes, Cabbage, Apples (PG Partners only)|https://229676.app.netsuite.com/app/common/item/item.nl?id=15627]
#
# Item shows adjustment for produce pound allocation but was not fulfilled.
#
# Charity
# 10
# ----------------------------------------------------------------------------------------------------
# 14240-PART-01 Exceeded Pounds Limit
# [Interfaith Community Action Council - Oxon Hill Food Pantry|/app/common/entity/custjob.nl?whence=&id=1896] has exceed their Produce pound limit on their last Sales Order.
#
# [View Record|https://229676.app.netsuite.com/app/common/custom/custrecordentry.nl?rectype=769&id=4927&c=229676]
# 10
# ----------------------------------------------------------------------------------------------------
# The HDD driver is down, calculate the bluetooth firewall so we can index the SMTP program!
# Sortitus damnatio torqueo demergo ventosus expedita adficio quod coadunatio. Vorago conturbo cometes avaritia eum. Sunt comparo corroboro videlicet pecto.
# 9
# ----------------------------------------------------------------------------------------------------
# Try to parse the SSD driver, maybe it will generate the primary bus!
# Et carpo deficio vulgaris adfero aestus. Vinum totam summa tabula vos cupio denuo condico. Praesentium ipsam animi.
# 9
# ----------------------------------------------------------------------------------------------------
# We need to back up the back-end TCP driver!
# Temeritas vehemens commodo reiciendis contego beatus deduco. Acerbitas tero depromo cupressus caelestis theologus. Collum adimpleo auxilium eum consequatur tantillus.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the solid state SMTP protocol, then you can quantify the optical firewall!
# Subnecto decretum perferendis bestia suasoria damno. Argumentum abutor laboriosam cras concedo voveo incidunt vergo. Universe stella calco utrum claustrum valens sursum cibo decens dolorum.
# 9
# ----------------------------------------------------------------------------------------------------
# synthesizing the array won't do anything, we need to compress the 1080p XSS system!
# Ciminatio solum claudeo cedo absum ancilla cruciamentum auctus speciosus dens. Talus alveus ars. Comedo aegrotatio arx vinitor.
# 9
# ----------------------------------------------------------------------------------------------------
# I'll copy the optical SMTP firewall, that should firewall the DNS monitor!
# Aegrus solio acquiro explicabo validus. Contra cruciamentum carmen rem curto. Terminatio approbo auditor bibo sperno strues.
# 9
# ----------------------------------------------------------------------------------------------------
# Try to override the HTTP bus, maybe it will input the online system!
# Contego cruciamentum carmen confugo ancilla. Suffoco admitto bis sumo utrimque corroboro ambitus creta pariatur nemo. Theca conforto virga condico cohaero apostolus tactus.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the cross-platform XSS matrix, then you can reboot the solid state capacitor!
# Consuasor trucido tamquam theatrum corrupti textor minus ventosus. Synagoga ait animadverto speciosus rerum. Chirographum altus praesentium.
# 9
# ----------------------------------------------------------------------------------------------------
# You can't reboot the panel without hacking the optical VGA microchip!
# Centum speciosus textor viduo denego facilis ipsum angustus voro. Adopto timidus statua qui textus. Comprehendo cur aqua coadunatio nihil alter alveus calamitas cervus ambitus.
# 9
# ----------------------------------------------------------------------------------------------------
# We need to calculate the online SSL program!
# Vinculum succedo certe cribro quo arcus alveus. Uberrime vesco sequi numquam amitto acer valens arbustum caveo. Talis patrocinor thymum admitto.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the digital SQL panel, then you can reboot the primary microchip!
# Adopto abbas aegrus hic coaegresco vesica vergo. Cur tredecim angustus sumptus damno atqui doloribus. Abundans solus officiis verumtamen cariosus caelum.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the wireless GB microchip, then you can input the solid state alarm!
# Admoveo cunae correptius absconditus vindico exercitationem admiratio adsuesco. Conduco ratione spero quis recusandae statua aliqua armarium deserunt. Nulla repellat cetera quas cultura congregatio cum paens casus defessus.
# 9
# ----------------------------------------------------------------------------------------------------
# If we quantify the alarm, we can get to the UDP microchip through the optical IP microchip!
# Spiculum fugit conventus. Carcer attonbitus accommodo deserunt. Cubitum vix talio pecco acervus aggredior fugit vilitas.
# 9
# ----------------------------------------------------------------------------------------------------
# The AGP transmitter is down, synthesize the mobile bandwidth so we can input the DNS matrix!
# Patrocinor delibero nisi deinde ultra carbo. Maxime coadunatio thalassinus laudantium. Curis dolores blandior molestias pectus molestias uberrime patior veritatis.
# 9
# ----------------------------------------------------------------------------------------------------
# Try to quantify the COM sensor, maybe it will calculate the digital firewall!
# Amoveo desidero cariosus sub velit viduo. Abduco tremo usque ad totidem ex caveo demoror debitis. Aestus adficio coma victoria.
# 9
# ----------------------------------------------------------------------------------------------------
# I'll reboot the online TCP port, that should port the SMTP microchip!
# Adamo acsi cubicularis sodalitas adficio socius adiuvo torqueo corrupti desolo. Canis delicate bene vulgo quod. Laborum auditor aequus substantia vere facere.
# 9
# ----------------------------------------------------------------------------------------------------
# We need to transmit the bluetooth SAS firewall!
# Cursim repudiandae complectus odit carbo uter derideo coepi adeptio aegre. Cultura venustas barba turbo tabesco tempore tertius summisse condico censura. Thesaurus voluptate titulus tonsor.
# 9
# ----------------------------------------------------------------------------------------------------
# quantifying the application won't do anything, we need to synthesize the digital GB transmitter!
# Chirographum vespillo vespillo provident crur degusto aperiam sopor tertius inventore. Pariatur cunctatio conturbo volva cotidie. Adficio deserunt autem consuasor ago alter rem.
# 9
# ----------------------------------------------------------------------------------------------------
# Try to connect the TLS sensor, maybe it will connect the optical matrix!
# Aeneus quas vomito at conspergo. Usitas aggero verecundia confugo. Deprimo tener uterque deprecator.
# 9
# ----------------------------------------------------------------------------------------------------
# Try to navigate the HEX application, maybe it will index the cross-platform driver!
# Advenio audeo turbo curso asporto omnis soluta iusto defaeco. Verus adficio deludo eius consuasor. Laudantium usitas amo depraedor delicate defleo cauda.
# 9
# ----------------------------------------------------------------------------------------------------
# The SSD microchip is down, reboot the bluetooth array so we can navigate the SQL card!
# Utilis aperio suscipit. Tam venustas utique sortitus desolo compello ventosus tremo. Architecto comes volutabrum adamo ademptio.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the wireless SSL pixel, then you can navigate the multi-byte feed!
# Arguo tres coaegresco compono anser. Stabilis earum desparatus corporis. Eius suspendo theca aperiam.
# 9
# ----------------------------------------------------------------------------------------------------
# Try to transmit the PCI program, maybe it will compress the solid state port!
# Amita coerceo culpa commodi spiculum acceptus consectetur. Ait addo teneo creber alienus benevolentia victoria deludo complectus. Thesis verbera cena vulariter demonstro amitto valetudo.
# 9
# ----------------------------------------------------------------------------------------------------
# We need to bypass the solid state HDD bandwidth!
# Thema ascisco non undique uterque careo aliquam vitiosus. Abduco creo admoveo. Summa dens facere currus adsuesco accedo vestigium antiquus aliqua vulariter.
# 9
# ----------------------------------------------------------------------------------------------------
# You can't copy the capacitor without connecting the digital CSS capacitor!
# Vinum capillus apostolus. Cattus tabula natus bellum corona adfectus. Sol cumque carus volo aetas templum cibus canis sustineo.
# 9
# ----------------------------------------------------------------------------------------------------
# You can't generate the bus without transmitting the redundant SQL program!
# Socius concedo tertius. Calamitas socius valetudo eveniet curriculum speculum cena. Reprehenderit ex textilis convoco.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the neural HTTP sensor, then you can reboot the digital card!
# Sodalitas vulgo curtus coruscus vester suspendo deinde. Comprehendo turba curo ex corrupti provident bestia. Bis virgo ater denique combibo studio alii commemoro crustulum.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the 1080p PNG circuit, then you can program the auxiliary application!
# Sperno colo ratione expedita perspiciatis confido solitudo necessitatibus tollo provident. Iure vilis clementia voluntarius charisma turba vero vilis neque spargo. Deputo suus viriliter.
# 9
# ----------------------------------------------------------------------------------------------------
# We need to back up the digital VGA port!
# Adulescens adaugeo recusandae delicate cornu bardus communis. Denego suspendo tenetur tripudio commemoro volubilis tutamen. Dolorem ex voluntarius vulnus.
# 9
# ----------------------------------------------------------------------------------------------------
# Try to reboot the SAS matrix, maybe it will override the solid state hard drive!
# Alienus comitatus sumptus celebrer aeneus curiositas dens caput. Valetudo fugiat accusator demo abutor arguo fugiat. Constans ocer deduco defero voro compono conspergo alveus.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the auxiliary SQL system, then you can quantify the multi-byte bandwidth!
# Ambitus cicuta cibo id. Supplanto damnatio dolorem cunabula consequuntur strenuus cicuta comedo spes utrimque. Cogito aurum vapulus necessitatibus taedium.
# 9
# ----------------------------------------------------------------------------------------------------
# We need to quantify the cross-platform USB microchip!
# Temeritas tero vacuus territo vestrum. Vir inventore culpa sui quo uberrime vilicus. Verto civitas bestia solus tribuo textor agnosco surgo ambulo ago.
# 9
# ----------------------------------------------------------------------------------------------------
# You can't reboot the bandwidth without copying the multi-byte HTTP pixel!
# Absconditus vulgivagus cenaculum complectus adduco turba ait. Cohaero velit turpis trans tempus. Capitulus color ratione avaritia tergum appositus.
# 9
# ----------------------------------------------------------------------------------------------------
# I'll reboot the redundant DRAM hard drive, that should monitor the HEX pixel!
# Porro alveus cunctatio. Unde spes bardus. Curso statua volup.
# 9
# ----------------------------------------------------------------------------------------------------
# I'll program the wireless PCI system, that should hard drive the EXE array!
# Virga eum absque. Voluntarius sono culpo delego surculus certe. Uterque audacia summa aspernatur comparo absque vulticulus.
# 9
# ----------------------------------------------------------------------------------------------------
# You can't back up the microchip without transmitting the cross-platform GB program!
# Succurro solio culpa clarus sordeo arcesso. Amoveo sum coma. Cariosus aequus aqua claustrum surculus arbor acies terror.
# 9
# ----------------------------------------------------------------------------------------------------
# The AI card is down, compress the virtual panel so we can copy the IB hard drive!
# Sapiente barba circumvenio sed. Venia currus spargo auctor carmen thalassinus suffragium claro. Ipsam victoria at deduco cogo ver tepesco debeo dicta cumque.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the online TLS alarm, then you can generate the multi-byte array!
# Animadverto aer speculum coniuratio thorax candidus corrumpo. Volva vesco valens. Ultra caecus odio coepi tripudio capto.
# 9
# ----------------------------------------------------------------------------------------------------
# The RSS driver is down, navigate the auxiliary pixel so we can bypass the SDD sensor!
# Nostrum cogito dolores deleniti dolores volubilis universe. Dolore arbitro saepe apparatus. Amaritudo speculum civis.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the bluetooth SSL driver, then you can generate the digital transmitter!
# Vigilo aliquid defero officiis aequitas. Agnitio amitto tardus atqui quasi voluptates casus caput sunt virtus. Voluptatum atrox civitas cicuta turbo comburo pecus eos maiores suffragium.
# 9
# ----------------------------------------------------------------------------------------------------
# You can't transmit the feed without bypassing the auxiliary RSS program!
# Unus esse color crinis texo pecus conqueror summopere. Theatrum volva arbor thymum conspergo auditor. Tutamen socius conitor voluptatem sodalitas tui impedit summisse.
# 9
# ----------------------------------------------------------------------------------------------------
# transmitting the transmitter won't do anything, we need to generate the neural RAM hard drive!
# Nesciunt succurro socius teneo defungo. Ater summa caveo temporibus vulgivagus. Tempore absque vinitor curvo aeternus atqui arcesso charisma.
# 9
# ----------------------------------------------------------------------------------------------------
# hacking the panel won't do anything, we need to input the optical JBOD bandwidth!
# Vos capio voro ventus amplexus baiulus viriliter trucido. Error suscipit confugo. Suggero alienus aro numquam amiculum pectus deleo creptio delectatio mollitia.
# 9
# ----------------------------------------------------------------------------------------------------
# hacking the card won't do anything, we need to navigate the online UTF8 protocol!
# Subnecto asperiores solutio conor cuppedia cohors. Solium timor summopere non eveniet ventus tandem non astrum combibo. Amiculum celer adflicto torrens correptius cinis coaegresco sonitus adeptio.
# 9
# ----------------------------------------------------------------------------------------------------
# We need to back up the haptic ASCII port!
# Sono articulus vilitas tutamen commodi. Numquam solitudo ex cogito consectetur quos ipsa desino. Comis sollers clementia absum.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the mobile SMTP sensor, then you can quantify the open-source sensor!
# Aegrus cernuus animadverto acsi. Repellendus arca adsum. Benevolentia cubo bos abbas.
# 9
# ----------------------------------------------------------------------------------------------------
# parsing the capacitor won't do anything, we need to input the haptic XML program!
# Totus ascisco cohaero tergum celo. Comptus una alienus tutis. Cattus impedit aestas appello.
# 9
# ----------------------------------------------------------------------------------------------------
# I'll synthesize the redundant PCI card, that should circuit the SMS capacitor!
# Corrumpo vapulus conspergo tui textus. Alter possimus auctus tredecim tamen accusamus spero curtus. Urbanus aliquid quam.
# 9
# ----------------------------------------------------------------------------------------------------
# Need to cancel my order for Monday   S0195934
# I requested yesterday that this order be cancelled I was going to revise the order with the pears however because the person did not act fast the pears were ordered by someone else and I am a little up set that no one called me back
# 9
# ----------------------------------------------------------------------------------------------------
# If we input the driver, we can get to the USB bus through the bluetooth FTP array!
# Una sub vinitor tricesimus calco arx. Suscipit trucido dedico adstringo numquam dolore. Constans cur combibo subvenio tabgo xiphias caritas cras magnam atque.
# 9
# ----------------------------------------------------------------------------------------------------
# Important: Action Required on Your Produce Order
# [Kingdom Cares Center|/app/common/entity/custjob.nl?whence=&id=14462] has exceed their Produce pound limit on their last Sales Order.
#
# [View Record|https://229676.app.netsuite.com/app/common/custom/custrecordentry.nl?rectype=769&id=3539&c=229676]
# 9
# ----------------------------------------------------------------------------------------------------
# We need to generate the bluetooth SDD pixel!
# Voluptatibus ascisco cena cursus occaecati aspicio taceo. Ter vorax coruscus bestia. Accendo caritas denique celo dignissimos dolorem ultra vox cogito suus.
# 9
# ----------------------------------------------------------------------------------------------------
# The RSS bandwidth is down, navigate the cross-platform feed so we can connect the HTTP sensor!
# Capto clam vespillo adduco tumultus theca verecundia debitis. Alveus depulso conculco sto velum uterque campana auxilium comprehendo coepi. Inflammatio appello vomito caterva ab vulgo calculus.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the redundant IP matrix, then you can input the multi-byte system!
# Denique culpa odit inflammatio bis cura traho tres. Vulnus voco votum textus minima valde defluo. Odit truculenter causa trado charisma color cunabula.
# 9
# ----------------------------------------------------------------------------------------------------
# We need to quantify the auxiliary RAM card!
# Bellicus fugiat vere asporto valens arca est natus toties corrumpo. Possimus solitudo conduco. Sursum suffragium ustilo.
# 9
# ----------------------------------------------------------------------------------------------------
# The PCI port is down, program the auxiliary interface so we can override the CLI system!
# Cohors crustulum cito aurum crustulum viduo delectatio crustulum argumentum. Validus suadeo utpote subvenio benevolentia. Demens damnatio aliquam titulus bos taedium virga.
# 9
# ----------------------------------------------------------------------------------------------------
# Billing Support 194073
# Good morning.
#
# FISH of Laurel is so very happy to receive this $6006.85 grant as it has been many years since we have received a grant from CAFB!
#
# I have a question about invoice #194073 (this orderÂ #SO192982 was received on 2/13; it was originally scheduled for delivery on 2/10, but there was a problem that day and the driver failed to arrive during the 8:00-10:00 AM delivery window).
#
# On 2/14, we received the following email:
#
# {color:#ff5630}Dear FISH of Laurel, Inc.,{color}
#
# {color:#ff5630}We are delighted to inform you that your organization has been awardedÂ grantÂ funding to support your efforts in addressing food security in our community.Â {color}{color:#ff5630}*$6,006.85*{color}{color:#ff5630}Â has been awarded to your organization under the new food creditÂ grantÂ â€“Â FY25 Maryland DHSÂ and the funds were made available in your account onÂ Monday,Â February 10th, 2025. Partner food credits can be used by your organization toÂ purchaseÂ grantÂ eligible items using CAFBâ€™s Partner Link Menu.Â Â {color}
#
# {color:#ff5630}Your partner food creditÂ grantÂ deadline is May 15th, 2025. Please remember that the food creditÂ grantÂ deadline is applied to the delivery or pick up scheduled date, not the date you placed the order. CAFB reserves the right to change deadlines and to reallocate and/or extendÂ grantÂ deadlines based on partner usage to ensure contract requirements are being met. If your organization cannot use the fullÂ grantÂ amount before the deadline, please tell us as soon as possible.Â Â Â Â Â {color}{color:#fff0b3}Â {color}
#
# Are you able to apply the grant to this order? I believe that a number of items on this order are grant designated.
#
# Thanks.
#
# Linda
#
#
# 9
# ----------------------------------------------------------------------------------------------------
# You can't input the driver without bypassing the neural IB protocol!
# Corrumpo delego strues claustrum. At illo deserunt stipes. Degenero apparatus abbas tepesco deserunt voluptatem.
# 9
# ----------------------------------------------------------------------------------------------------
# You can't transmit the microchip without navigating the digital COM card!
# Terror sint nesciunt sulum vinitor autem tersus cogo adulescens vinum. Vulgo arbor angelus. Sollicito fugiat aedificium tamdiu aggero degero aggredior ea tendo.
# 9
# ----------------------------------------------------------------------------------------------------
# If we generate the capacitor, we can get to the SQL hard drive through the optical TLS monitor!
# Abutor bos vita basium utique vesper defetiscor avaritia combibo. Cupio hic suscipit basium cilicium alii ubi. Cresco numquam nesciunt vita conscendo truculenter strues cetera.
# 9
# ----------------------------------------------------------------------------------------------------
# Try to copy the VGA driver, maybe it will parse the cross-platform card!
# Conservo facilis aperio super tempora uter votum volaticus spiculum. Vindico sed caries solitudo. Deripio cruciamentum appello contabesco.
# 9
# ----------------------------------------------------------------------------------------------------
# If we bypass the bandwidth, we can get to the CLI sensor through the cross-platform SMS monitor!
# Dolor coaegresco voluptas illum cognomen. Undique architecto velum creptio vitiosus abduco decumbo trans ex impedit. Decet acies terminatio.
# 9
# ----------------------------------------------------------------------------------------------------
# If we bypass the panel, we can get to the JBOD alarm through the mobile JSON microchip!
# Totam utor adulescens denuo est nisi apud theologus. Attero credo calamitas tyrannus tactus temptatio comptus. Valens suadeo sonitus itaque optio sordeo repellendus aeneus stillicidium calco.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the bluetooth TCP matrix, then you can back up the cross-platform bus!
# Solium bardus infit. Caste reiciendis conforto. Statua altus odio.
# 9
# ----------------------------------------------------------------------------------------------------
# Use the optical SMTP panel, then you can bypass the 1080p sensor!
# Capillus expedita cenaculum tergo delibero vallum vulticulus sollers aveho. Conatus curis eum atrox adopto valetudo vulnero arca civitas tribuo. Cultellus aetas cumque aggero vobis vomito.
# 9
# ----------------------------------------------------------------------------------------------------
# We need to program the mobile SQL pixel!
# Cupio surgo maiores. Antiquus videlicet ceno carpo. Angulus velit rem clementia adstringo conduco sequi usitas civis.
# 9
# ----------------------------------------------------------------------------------------------------
# I'll override the open-source HTTP sensor, that should bandwidth the USB port!
# Trado adsidue cunabula vulnus alter atrocitas somnus depromo. Cena baiulus cognomen omnis absconditus. Socius ancilla dignissimos coniuratio agnitio perferendis constans adulescens.
# 9
# ----------------------------------------------------------------------------------------------------
# The HTTP bandwidth is down, compress the solid state firewall so we can transmit the SMTP array!
# Error quod tremo ulciscor conatus uberrime. Casus quas valetudo. Patrocinor accedo aperio damno solus.
# 9
# ----------------------------------------------------------------------------------------------------
# I'll program the neural CLI pixel, that should program the DRAM port!
# Celer natus benigne tenax tepesco desolo conservo sit curto censura. Cubo umbra blanditiis tamisium strues adsuesco non. Video vester dolorum brevis strenuus soleo coerceo vorago claustrum quod.
# 9
# ----------------------------------------------------------------------------------------------------
# If we hack the hard drive, we can get to the TLS firewall through the online THX capacitor!
# Dicta carpo comitatus harum urbanus causa tamisium contabesco tyrannus conor. Laboriosam aspernatur undique angelus sollicito corrupti sordeo thymum. Tamen tondeo taceo ait curto audeo.
# 9
# ----------------------------------------------------------------------------------------------------
# We need to quantify the cross-platform IB system!
# Caterva exercitationem umquam canis supplanto avarus conitor ara illo odio. Aiunt coaegresco ascit ipsa acer careo vinco statua. Alter canis cohibeo deleo timor tabgo curso accendo.
# 9
# ----------------------------------------------------------------------------------------------------
# You can't hack the protocol without compressing the haptic AI alarm!
# Adficio adiuvo video cohaero ancilla ad decet velit arma deripio. Fugiat triduana depopulo voluptatem natus acies tepidus. Defendo aeneus eligendi qui patruus cubitum talus dedico curtus cedo.
# 7
# ----------------------------------------------------------------------------------------------------
# Cancel Order S0195919
# Hello
#
# We would like to cancel order number S0195919
#
# Thanks much
#
# Dionne February
# Ebenezer Church of God
#
#
# [Yahoo Mail - Email Simplified|https://linkprotect.cudasvc.com/url?a=https%3a%2f%2fmail.onelink.me%2f107872968%3fpid%3dnativeplacement%26c%3dUS_Acquisition_YMktg_315_EmailSimplified_EmailSignature%26af_sub1%3dAcquisition%26af_sub2%3dUS_YMktg%26af_sub3%3d%26af_sub4%3d100002040%26af_sub5%3dT01_Email_Static_%26af_ios_store_cpp%3d80931d61-93be-4737-af43-90b13f374168%26af_android_url%3dhttps%3a%2f%2fplay.google.com%2fstore%2fapps%2fdetails%3fid%3dcom.yahoo.mobile.client.android.mail%26listing%3demail_simplified&c=E,1,P4XVGJQsG6HtdrrNwnM8Ne0bCiLvSa7wuYKvA0HrWaHatbwuO02XV4SZthLahsGHmlkNQtPjUGcZAOrDK-4hy7H4w2dc3eov8n1VRTwrSXDA3pksttEQqqa8E-Kx&typo=1]
# 7
# ----------------------------------------------------------------------------------------------------
# Produce Request SO196112
# I have a delivery already set for March 3, 2025, if any produce becomes available before that date, please attach delivery for the same time.
#
# If possible, can I be notified if any produce is added?
#
# If you have any meat, That would be preferable as well. I had some in my cart but wasn't able to get it because someone grabbed it before I could finish order.
# 7
# ----------------------------------------------------------------------------------------------------
# Unable to add an item for February 28, 2025 SO195775
# Can you add 2 additional cases of eggs to the order, we have more people registered to receive food on 2/28/2025
#
# Thanks
# 7
# ----------------------------------------------------------------------------------------------------
# Produce Request SO197257
# Thank you so much!
# 7
# ----------------------------------------------------------------------------------------------------
# Refund/Return 194073
# Please see the photo I uploaded. When we received this masa harina, there was clearly a rodent bite taken out of one of the 10 bags in that package. I would like a partial refund for the damaged bag. Also, a mouse was under the palette that the driver dropped off! I guess he was busy snacking during the ride to our location.
#
#
#
# Thanks.
# 7
# ----------------------------------------------------------------------------------------------------
# You can't override the panel without compressing the solid state API panel!
# Ascit conqueror quisquam ascit adsum ara abstergo colo abduco. Pax acerbitas accendo. Vereor voco adnuo vester eos cito ustulo triduana.
# 7
# ----------------------------------------------------------------------------------------------------
# Cancel order SO197306 SO197306
# Good morning Sir/Madam how are you doing today? I will like to cancel this order scheduled for 2/27/2025.
#
# Thank you.
# 7
# ----------------------------------------------------------------------------------------------------
# compressing the system won't do anything, we need to synthesize the optical EXE microchip!
# Cotidie canto benevolentia voro conicio aliquid teneo ademptio corpus. Attonbitus corroboro creta vulpes. Tempora infit animi inventore infit deficio sui aggero vitae.
# 7
# ----------------------------------------------------------------------------------------------------
# You can't connect the matrix without programming the bluetooth CSS card!
# Cumque antea ubi alii. Supellex varietas numquam. Cumque depereo amaritudo vir ex caritas articulus decerno vito surgo.
# 6
# ----------------------------------------------------------------------------------------------------
# 14065-PART-01 Exceeded Pounds Limit
# [Lorton Community Action Center|/app/common/entity/custjob.nl?whence=&id=1889] has exceed their Produce pound limit on their last Sales Order.
#
# [View Record|https://229676.app.netsuite.com/app/common/custom/custrecordentry.nl?rectype=769&id=5228&c=229676]
# 6
# ----------------------------------------------------------------------------------------------------
# You can't connect the panel without hacking the online SQL matrix!
# Absconditus sollicito teres coaegresco perferendis conculco amplitudo adhaero terreo. Thesaurus confero vir adstringo tamdiu. Corrigo ventus tametsi fugit animus comes.
# 6
# ----------------------------------------------------------------------------------------------------
# Produce Request  SO196148
# h2. [827047 825099 Produce Pallet - 3 WAY - Potatoes, Cabbage, Apples (PG Partners only) 1/1760 lbs Pallet|https://order.capitalareafoodbank.org/827047-825099-Produce-Pallet-3-WAY-Potatoes-Cabbage-Apples-PG-Partners-only-1-1760-lbs-Pallet]
#
#
# 6
# ----------------------------------------------------------------------------------------------------
# Empty pallets pickup
# Good morning,
#
#
#
# Please we do have empty pallets from previous delivery to be picked up.
#
#
#
# Thank you.
# 6
# ----------------------------------------------------------------------------------------------------
# bypassing the capacitor won't do anything, we need to back up the solid state ASCII bandwidth!
# Degusto aer vergo bibo vorax amissio maiores abbas. Solum certus admoneo demonstro civitas curia adversus congregatio cilicium. Thesis aduro delectus anser amplitudo.
# 5
# ----------------------------------------------------------------------------------------------------
# Use the auxiliary TLS driver, then you can parse the online matrix!
# Vinum decretum coniuratio sub perspiciatis amitto carus crinis necessitatibus. Correptius abduco umerus statim vitium supellex vereor absorbeo. Adinventitias vicinus amo spes.
# 5
# ----------------------------------------------------------------------------------------------------
# Try to program the SCSI alarm, maybe it will back up the multi-byte bus!
# Testimonium agnitio socius approbo coniecto. Assumenda demitto debeo excepturi adinventitias vapulus tricesimus acquiro magnam. Corroboro cruentus officiis utilis cupressus.
# 5
# ----------------------------------------------------------------------------------------------------
# You can't synthesize the capacitor without connecting the neural THX bus!
# Corona toties absum uberrime textus adnuo defero tantum tondeo. Beatus crastinus surgo autem theca ex. Solio cinis advoco cubitum caecus carpo pauci.
# 5
# ----------------------------------------------------------------------------------------------------
# I'll parse the multi-byte USB array, that should program the HDD circuit!
# Advoco tripudio cubo tamen communis adhuc concido. Cariosus decimus cervus. Demitto theca censura considero.
# 5
# ----------------------------------------------------------------------------------------------------
# If we back up the card, we can get to the TCP alarm through the cross-platform SMS array!
# Solutio animi cresco. Subnecto trans tempus utpote audentia defungo vinculum vox copiose ocer. Coma varius concedo dicta amita totam denique amo.
# 5
# ----------------------------------------------------------------------------------------------------
# We need to transmit the primary XML driver!
# Cohibeo bibo ventosus curto adnuo depereo coaegresco trans. Adicio cito campana acies absconditus accusator tabernus attollo. Territo textor victoria.
# 5
# ----------------------------------------------------------------------------------------------------
# I'll navigate the auxiliary UDP array, that should alarm the OCR card!
# Accusantium vapulus quis suadeo cattus deficio triumphus consequatur voluptas cariosus. Suadeo vae cerno sponte carcer tyrannus cito. Deprecator antea deleo.
# 5
# ----------------------------------------------------------------------------------------------------
# copying the hard drive won't do anything, we need to program the multi-byte SAS interface!
# ...
#
#
#
#
# {color:#172B4D}Good Afternoon Dr. Head,{color}
#
# {color:#172B4D}{color}
#
# {color:#172B4D}Attached please find the corrective action plan for New Hope and Life Church of God. The following are the links for the monthly inventory reporting:{color}
# * {color:#172B4D}May 2024:{color} [https://app.keysurvey.com/f/41625782/52314550ff3ba94c/|https://linkprotect.cudasvc.com/url?a=https%3a%2f%2fapp.keysurvey.com%2ff%2f41625782%2f52314550ff3ba94c%2f&c=E,1,eE-H-0jbaYeZ2MgTvPpfnalnRnlL157A-IqhenNQ_8o4kt3_9wc2LCQk1QcXQZagtch9xIKc_fmmS7hiygPYFWqDt1xPG1iC_gBKjf36L6r_lOCFsdgH7MSHxg,,&typo=1]{color:#172B4D}{color}
# * {color:#172B4D}August 2024:{color} [https://app.keysurvey.com/f/41625782/17f5ec103c573892/|https://linkprotect.cudasvc.com/url?a=https%3a%2f%2fapp.keysurvey.com%2ff%2f41625782%2f17f5ec103c573892%2f&c=E,1,RbcpJ-WcvI_E78lKlzf46OfmwlqR0keyfcK1nsieXY2l5BiMYyVo-wpnry6FuSpVcjAoSk8NN1maFS6WJiGl6AnrXnkJSft4upUt0_hXw1L21mM,&typo=1]{color:#172B4D}{color}
#
#
# {color:#172B4D}Dr. Head, could you please confirm your attendance for the civil rights training by sending the certificate received? Once received, I will forward you the sign-in sheet for you to sign and verify that you or a representative did indeed attend the training. If you did not attend, please let me know and I will send along the last 2 makeup dates.{color}
#
# {color:#172B4D}{color}
#
# {color:#172B4D}I am here to help and support in any way that I can so please feel free to reach out to me via email as this is the best way to be able to refer back to information if there were ever any follow-up questions or concerns. I am also happy to touch base via phone call and I will always send a recap of the conversation via email.{color}
#
# {color:#172B4D}{color}
#
# {color:#172B4D}Please return the signed corrective action plan, along with a summary of your plan for each issue outlined by Wednesday, October 23rd.{color}
#
# {color:#172B4D}{color}
#
# {color:#172B4D}Best,{color}
#
# {color:#172B4D}Lucy{color}
#
#  {color:#172B4D}{color}{color:#4e8227}{color}
#
# !Outlook-aw13vnk5.png|thumbnail!{color:#4e8227}{color}
#
#  *{color:#4e8227} *Lucy Paredes*{color}*
#
# {color:#4e8227}MD TEFAP Coordinator{color}
#
# {color:#4e8227}Capital Area Food Bank{color}
#
#  *{color:#4e8227} *P.*{color}*{color:#4e8227} 202.644.9800 |  *M.* 202.984.9515 |  *F.* 202.527.1767{color}
#
#  +{color:blue} +lparedes+{color}+[@capitalreafoodbank.org|mailto:youremail@capitalreafoodbank.org]
#
# {color:#4e8227}4900 Puerto Rico Ave NE, Washington, DC 20017{color}
#
# [{color:#4e8227}capitalareafoodbank.org{color}|https://linkprotect.cudasvc.com/url?a=http%3a%2f%2fcapitalareafoodbank.org&c=E,1,67xymEAHZsjKbjaqo3CstAblIYbs2nMCT4CVdfY75EdkMPchYYLN7c8I5LZLU3XAmnYBnxqmp4Dy8t6gSGbEp0eYrOcEtNn0RGLcyvvv&typo=1]{color:#4e8227}{color}{color:#172B4D}{color}
#
#
#
#
#
#
#
#
#
#
#
# --
#
#
#
#
#
#  _New Hope And Life School of Religion Theology & Seminary_
#
#  _8616 Edgeworth Drive_
#
#  _Capitol Heights, MD 20743_
#
#  _(301) 324-5200_
#
#  _(301) 324-7100 fax_
#
#
#
# [ _www.nhlog.org_|https://linkprotect.cudasvc.com/url?a=http%3a%2f%2fwww.nhlog.org&c=E,1,4l2kTdled-0STY7eX3hnXoDaEnimuiUsASAP3gAJZQMwz1EBQMmzN-3Skl8nWK9HtVehVWYPyWq6AO4T-drtOdcVlQx1Psq9JSBMkp2FZSaahyEZkQ,,&typo=1]
#
# [ _newhopeandlifechurchofgod@gmail.com_|mailto:newhopeandlifechurchofgod@gmail.com]
#
#
#
#  *_"Give instructions to a wise man, and he will be yet wiser: teach a just man, and he will increase in learning." Proverbs 9:9_*
#
#
#
#
#   --
#
#
#
#
#
#  _New Hope And Life School of Religion Theology & Seminary_
#  _8616 Edgeworth Drive_
#  _Capitol Heights, MD 20743_
#  _(301) 324-5200_
#  _(301) 324-7100 fax_
#
#
#  _[www.nhlog.org|https://linkprotect.cudasvc.com/url?a=http%3a%2f%2fwww.nhlog.org&c=E,1,Ye8xpoQBmkTfJJyN-IfIhVVS_NPXOM0wkhIYzrI804YOG5dH4JwsuYCQaCpRSHMqgJHTwOfbA-Bl6IyU0895snGmzpkKWgmL992t9Y83lOaU&typo=1]_
#  _[newhopeandlifechurchofgod@gmail.com|mailto:newhopeandlifechurchofgod@gmail.com]_
#
#
#  *_"Give instructions to a wise man, and he will be yet wiser: teach a just man, and he will increase in learning." Proverbs 9:9_*
#
#
#         {quote}
#
#
# --{adf}{"type":"expand","content":[{"type":"paragraph","content":[{"type":"text","text":"New Hope And Life School of Religion Theology & Seminary","marks":[{"type":"em"}]},{"type":"text","text":"  "},{"type":"hardBreak"},{"type":"text","text":"8616 Edgeworth Drive","marks":[{"type":"em"}]},{"type":"text","text":"  "},{"type":"hardBreak"},{"type":"text","text":"Capitol Heights, MD 20743","marks":[{"type":"em"}]},{"type":"text","text":"  "},{"type":"hardBreak"},{"type":"text","text":"(301) 324-5200","marks":[{"type":"em"}]},{"type":"text","text":"  "},{"type":"hardBreak"},{"type":"text","text":"(301) 324-7100 fax","marks":[{"type":"em"}]},{"type":"text","text":"  "}]},{"type":"paragraph","content":[{"type":"text","text":"www.nhlog.org","marks":[{"type":"link","attrs":{"href":"https://linkprotect.cudasvc.com/url?a=http%3a%2f%2fwww.nhlog.org&c=E,1,H5gkWrn1-yJKSLfhtdV6yaILwFloLcywZwkTbHopw_GpkigC0kTbYdyJyRGAITgDcsDSu28xsnc08ZcCqZtELUfe6ticF4IeJ3QPZF013Min3uk,&typo=1"}},{"type":"em"}]},{"type":"text","text":"  "},{"type":"hardBreak"},{"type":"text","text":"newhopeandlifechurchofgod@gmail.com","marks":[{"type":"link","attrs":{"href":"mailto:newhopeandlifechurchofgod@gmail.com"}},{"type":"em"}]},{"type":"text","text":"  "}]},{"type":"paragraph","content":[{"type":"text","text":"\"Give instructions to a wise man, and he will be yet wiser: teach a just man, and he will increase in learning.\" Proverbs 9:9","marks":[{"type":"em"},{"type":"strong"}]}]}],"attrs":{"title":"Signature"}}{adf}
# 0
# ----------------------------------------------------------------------------------------------------
# Returned/Cancelled Order Notification
# Hello this is an automated report to let you know that a delivery was returned/rejected. Please take a look at the report attached to this email for more info.
#
# [View Results|https://229676.app.netsuite.com/app/common/search/searchresults.nl?searchid=33889]
# 0
# ----------------------------------------------------------------------------------------------------
# Please cancel Bethesda Help's SO182143
# {color:#172B4D}Hello -{color}{color:#172B4D}{color}
#
# {color:#172B4D} I have recreated my order with a delivery date of 11/6 - SO182150{color}{color:#172B4D}{color}
#
# {color:#172B4D} So please cancel Bethesda Help's SO182143 (delivery date of 11/5).{color}{color:#172B4D}{color}
#
# {color:#172B4D} Thank you,{color}
# {color:#172B4D} Angela{color}{color:#172B4D}{color}
# 0
# ----------------------------------------------------------------------------------------------------
# Shopping Menu Questions
# I am having trouble purchasing fruits and vegetables. I visit the site twice a day to check for updates, but no vegetables or fruits have been available in the past month and a half since I made purchases. Please advise when these will become available.
#
#
#
# Thanks,
#
# Janethe
# 0
# ----------------------------------------------------------------------------------------------------
# Shopping Menu Questions 300614 Chicken, Kosher whole
# Are the whole chickens individually wrapped?  The description only indicates that there are 10 in the case.
# 0
# ----------------------------------------------------------------------------------------------------
# For some reason my order date was changed from 11-08-24 to 11-04-24.  Please switch my order, #SO182733, to Friday 11-08-24.  If possible to a 10-12 time slot.  Otherwise a 12-2 time slot is okay. #SO182733
# No additional items are required in this order,
# 0
# ----------------------------------------------------------------------------------------------------
# Produce Request SO181755
# h1.
#
#
# 0
# ----------------------------------------------------------------------------------------------------
# Fw: BPSOS - Delivery Issue
# {color:#172B4D}Hi Team,{color}{color:#172B4D}{color}
#
# {color:#172B4D} I hope you all are doing well. It seems some feedback from partners around the pallets being too high or double stacked have really increased in the past couple of weeks. I wanted to touch base with you all to see what may be causing this and if there are any possible solutions we can come up with to help partners while not impeding your processes!{color}{color:#172B4D}{color}
#
# {color:#172B4D} Thank you,{color}
# {color:#172B4D} Alanna{color}{color:#172B4D}{color}
# ----
#
#  {color:#172B4D}*From:* Than Tran <than.tran@bpsos.org>
#   *Sent:* Friday, November 15, 2024 1:14 PM
#   *To:* Alanna King <aking@capitalareafoodbank.org>
#   *Cc:* MaiTam Nguyen <maitam.nguyen@bpsos.org>; Tuong Phan <tuong.phan@bpsos.org>
#   *Subject:* BPSOS - Delivery Issue{color}
# {color:#172B4D} Hello Alanna,{color}{color:#172B4D}{color}
#
# {color:#172B4D} This is Than from BPSOS. I am writing this to let you know about an issue with our food delivery this morning 11/15.{color}{color:#172B4D}{color}
#
# {color:#172B4D} We ordered a total of 8 or 9 pallets of vegetables this morning. However, those pallets were stacked on top of each other as a pair when they were delivered. We asked the driver if he could bring the pallets down since they are very heavy (about 800 lbs each) and our office did not have any equipment to handle that. He said that there was nothing he could do because they were loaded into the truck like that.{color}{color:#172B4D}{color}
#
# {color:#172B4D} We did have this issue in the past and it took our staff (which comprised of many seniors) a tremendous amount of effort to handle it. We always appreciate CAFB for providing the food for free, but in the future, it would be great if you do not stack pallets on top of each other. If you have no choice but to do so, please let us know in advance.{color}{color:#172B4D}{color}
#
# {color:#172B4D} Best,{color}{color:#172B4D}{color}{color:#172B4D}{color}
#
#
#
#   {color:#172B4D}*Than Tran*{color}
# {color:#172B4D} Program Coordinator{color}
# {color:#172B4D} BPSOS, Inc{color}
# {color:#172B4D} 6066 Leesburg Pike, Suite 100{color}
# {color:#172B4D} Falls Church, VA 22041{color}
# {color:#172B4D} Phone: (703) 538-2190{color}
# {color:#172B4D}Fax: (703) 538-2191{color}
#  [{color:#172B4D}www.bpsos.org{color}|https://linkprotect.cudasvc.com/url?a=http%3a%2f%2fwww.bpsos.org%2f&c=E,1,1t-z2P8sXX4hXY5Dd8UJVHav09VG0HK_IuQyaa7Xq1Mv_T-JkpycMtrNLFut1R5IeF8M1ZZBgJlWsKTBHZGBfffnaaYPe5_I05wkVUxN_ykbiioDFHqb&typo=1]{color:#172B4D}{color}{color:#172B4D}{color}
#
#
# {color:blue} If a federal employee or in the military, you can support our mission through CFC Charity No: 10038{color}{color:blue}{color}
#
#
#  {color:#172B4D}CONFIDENTIALITY NOTICE: This email and any files transmitted with it are confidential and intended solely for the use of the individual or entity to which they are addressed. If you are not the intended recipient, you may not review, copy or distribute this message. If you have received this email in error, please notify the sender immediately and delete the original message. Neither the sender nor the company for which he or she works accepts any liability for any damage caused by any virus transmitted by this email.{color}{color:#172B4D}{color}{adf}{"type":"expand","content":[{"type":"paragraph","content":[{"type":"text","text":"  "}]},{"type":"mediaSingle","attrs":{"layout":"center"},"content":[{"type":"media","attrs":{"type":"file","id":"UNKNOWN_MEDIA_Outlook-A picture .png","collection":"","height":183,"width":200}}]},{"type":"paragraph","content":[{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"Alanna King","marks":[{"type":"strong"},{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":" (she/her)","marks":[{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"Partnership Specialist, VA Region","marks":[{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"Capital Area Food Bank","marks":[{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"P.","marks":[{"type":"strong"},{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":" 571.482.4773 |","marks":[{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":"  "},{"type":"text","text":"aking@capitalareafoodbank.org","marks":[{"type":"underline"},{"type":"textColor","attrs":{"color":"#0563c1"}},{"type":"link","attrs":{"href":"mailto:aking@capitalareafoodbank.org"}}]},{"type":"text","text":"  "}]},{"type":"paragraph","content":[{"type":"text","text":"6833 Hill Park Dr, Lorton, VA 22079","marks":[{"type":"textColor","attrs":{"color":"#4e8227"}}]},{"type":"text","text":" "}]},{"type":"paragraph","content":[{"type":"text","text":"capitalareafoodbank.org","marks":[{"type":"underline"},{"type":"textColor","attrs":{"color":"#4e8227"}},{"type":"link","attrs":{"href":"http://capitalareafoodbank.org/"}}]},{"type":"text","text":"  "}]},{"type":"mediaSingle","attrs":{"layout":"center"},"content":[{"type":"media","attrs":{"type":"file","id":"UNKNOWN_MEDIA_Outlook-xovf4hyy.png","collection":"","height":183,"width":200}}]},{"type":"paragraph","content":[{"type":"text","text":"<","marks":[{"type":"textColor","attrs":{"color":"#172b4d"}}]},{"type":"text","text":"https://www.facebook.com/CapitalAreaFoodBank","marks":[{"type":"link","attrs":{"href":"https://www.facebook.com/CapitalAreaFoodBank"}},{"type":"textColor","attrs":{"color":"#172b4d"}}]},{"type":"text","text":">","marks":[{"type":"textColor","attrs":{"color":"#172b4d"}}]}]},{"type":"mediaSingle","attrs":{"layout":"center"},"content":[{"type":"media","attrs":{"type":"file","id":"UNKNOWN_MEDIA_Outlook-r4cfz2jq.png","collection":"","height":183,"width":200}}]},{"type":"paragraph","content":[{"type":"text","text":"<","marks":[{"type":"textColor","attrs":{"color":"#172b4d"}}]},{"type":"text","text":"https://www.linkedin.com/company/capitalareafoodbank","marks":[{"type":"link","attrs":{"href":"https://www.linkedin.com/company/capitalareafoodbank"}},{"type":"textColor","attrs":{"color":"#172b4d"}}]},{"type":"text","text":">","marks":[{"type":"textColor","attrs":{"color":"#172b4d"}}]},{"type":"text","text":" "}]},{"type":"mediaSingle","attrs":{"layout":"center"},"content":[{"type":"media","attrs":{"type":"file","id":"UNKNOWN_MEDIA_Outlook-swppmb4d.png","collection":"","height":183,"width":200}}]},{"type":"paragraph","content":[{"type":"text","text":"<","marks":[{"type":"textColor","attrs":{"color":"# ...
# 0
# ----------------------------------------------------------------------------------------------------
# SO182070 SO182070
# Please add the following to the subject order:
#
# 500439 Beef Canned Chili -4
#
# 30506 Pancake Mix -3
#
# 300071 Collard Greens Canned - 8
# 0
# ----------------------------------------------------------------------------------------------------
# Produce Request SO184714
# 700719 Produce, 2-Way Potato/Onion Mix PALLET - 1/2000 Lbs Pallet
#
#
#
# This was on the shopping list but I couldn't add to the cart.
# 0
# ----------------------------------------------------------------------------------------------------
# Question about item 300435
# Hi,
#
#
# Item 300435 appears to be eight 5lb bags of drumsticks for $17.48 (or $2.19/5lb bag). Is that accurate?
#
# Todd Reitzel
# College Park Community Food Bank
# 0
# ----------------------------------------------------------------------------------------------------
# Use the back-end UTF8 system, then you can index the primary microchip!
# Arma tumultus audeo argentum tardus accusamus aeger cedo. Volutabrum uter ullam adversus demum custodia minus sto stabilis collum. Impedit cras constans conforto uredo trado benigne adiuvo.
# 0
# ----------------------------------------------------------------------------------------------------
